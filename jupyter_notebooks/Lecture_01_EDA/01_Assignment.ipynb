# %%
import numpy as np
import pandas as pd
pd.set_option('display.max.columns', 100)
# to draw pictures in jupyter notebook
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../adult.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# salary            32561 non-null int64
# dtypes: int64(7), object(8)
# memory usage: 3.7+ MB

# %%
#df['salary']= df['salary'].replace('<=50K', '50')
df['salary'] = df['salary'].str.replace('<=50K','50')
df['salary'] = df['salary'].str.replace('>50K','51')
df['salary'] = df['salary'].astype('int64')

# %%
df
# Out:
#        age workclass  fnlwgt   education  education-num       marital-status  \
# 0       17         ?  304873        10th              6        Never-married
# 1       17   Private   65368        11th              7        Never-married
# 2       17   Private  245918        11th              7        Never-married
# 3       17   Private  191260         9th              5        Never-married
# 4       17   Private  270942     5th-6th              3        Never-married
# ...    ...       ...     ...         ...            ...                  ...
# 32556   90   Private   46786   Bachelors             13   Married-civ-spouse
# 32557   90   Private  175491     HS-grad              9   Married-civ-spouse
# 32558   90   Private   88991   Bachelors             13   Married-civ-spouse
# 32559   90   Private  206667     Masters             14   Married-civ-spouse
# 32560   90         ?  313986     HS-grad              9   Married-civ-spouse
#
# ...

# %%
df['salary'].astype(bool).astype('int')
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 32556    1
# 32557    1
# 32558    1
# 32559    1
# 32560    1
# Name: salary, Length: 32561, dtype: int64

# %%
df
# Out:
#        age workclass  fnlwgt   education  education-num       marital-status  \
# 0       17         ?  304873        10th              6        Never-married
# 1       17   Private   65368        11th              7        Never-married
# 2       17   Private  245918        11th              7        Never-married
# 3       17   Private  191260         9th              5        Never-married
# 4       17   Private  270942     5th-6th              3        Never-married
# ...    ...       ...     ...         ...            ...                  ...
# 32556   90   Private   46786   Bachelors             13   Married-civ-spouse
# 32557   90   Private  175491     HS-grad              9   Married-civ-spouse
# 32558   90   Private   88991   Bachelors             13   Married-civ-spouse
# 32559   90   Private  206667     Masters             14   Married-civ-spouse
# 32560   90         ?  313986     HS-grad              9   Married-civ-spouse
#
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df["native-country"].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
# 1. How many men and women (sex feature) are represented in this dataset?

# %%
df["sex"].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %%
#2. What is the average age (age feature) of women?

# %%
df['sex'] = df['sex'].str.replace('Male','1')
df['sex'] = df['sex'].str.replace('Female','0')
df['sex'] = df['sex'].astype('int64')

# %%
female_avg_age = df[df['sex'] == 0]['age'].mean()
print("Female Avg Age: ",female_avg_age )
# Out:
# Female Avg Age:  36.85823043357163

# %%
# 3. What is the percentage of German citizens (native-country feature)?

# %%
df['native-country'] = df['native-country'].str.replace('Germany','1')

# %%
#4-5. What are the mean and standard deviation of age for 
# those who earn more than 50K per year (salary feature) and those who earn less than 50K per year?

# %%
more_std = df[df['salary'] == 51]['age'].std()
more_mean = df[df['salary'] == 51]['age'].mean()
print("More then 50K STD :", more_std)
print("More then 50K Mean :", more_mean)
# Out:
# More then 50K STD : 10.519027719851975
# More then 50K Mean : 44.24984058155847

# %%
less_std = df[df['salary'] == 50]['age'].std()
less_mean = df[df['salary'] == 50]['age'].mean()
print("Less then 50K STD :", less_std)
print("Less then 50K Mean :", less_mean)
# Out:
# Less then 50K STD : 14.020088490824692
# Less then 50K Mean : 36.78373786407767

# %%
#6. Is it true that people who earn more than 50K have at least high school education? 
# (education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters or Doctorate feature)

# %%
more_education = df[df['salary'] == 51]['education']
more_education = more_education.value_counts()
print(more_education)
# Out:
#  Bachelors       2221
#  HS-grad         1675
#  Some-college    1387
#  Masters          959
#  Prof-school      423
#  Assoc-voc        361
#  Doctorate        306
#  Assoc-acdm       265
#  10th              62
#  11th              60
#  7th-8th           40
#  12th              33
#  9th               27
#  5th-6th           16
#  1st-4th            6
# Name: education, dtype: int64

# %%
# 7. Display age statistics for each race (race feature) and each gender (sex feature). 
# Use groupby() and describe(). Find the maximum age of men of Amer-Indian-Eskimo race.

# %%
dk = df.groupby(['sex', 'race'])
dk.describe()
# Out:
#                              age                                          \
#                            count       mean        std   min   25%   50%
# race                sex
#  Amer-Indian-Eskimo 0      119.0  37.117647  13.114991  17.0  27.0  36.0
#                     1      192.0  37.208333  12.049563  17.0  28.0  35.0
#  Asian-Pac-Islander 0      346.0  35.089595  12.300845  17.0  25.0  33.0
#                     1      693.0  39.073593  12.883944  18.0  29.0  37.0
#  Black              0     1555.0  37.854019  12.637197  17.0  28.0  37.0
#                     1     1569.0  37.682600  12.882612  17.0  27.0  36.0
#  Other              0      109.0  31.678899  11.631599  17.0  23.0  29.0
#                     1      162.0  34.654321  11.355531  17.0  26.0  32.0
#  White              0     8642.0  36.811618  14.329093  17.0  25.0  35.0
#                     1    19174.0  39.652498  13.436029  17.0  29.0  38.0
#
# ...

# %%
# 8. Among whom is the proportion of those who earn a lot (>50K) greater: married or single men 
# (marital-status feature)? Consider as married those who have a marital-status starting with Married 
  #  (Married-civ-spouse, Married-spouse-absent or Married-AF-spouse), the rest are considered bachelors.

# %%
more_married = df[df['salary'] == 51]['marital-status']
more_married = more_married.value_counts()
print(more_married)
# Out:
#  Married-civ-spouse       6692
#  Never-married             491
#  Divorced                  463
#  Widowed                    85
#  Separated                  66
#  Married-spouse-absent      34
#  Married-AF-spouse          10
# Name: marital-status, dtype: int64

# %%
more_married = df[(df['salary'] == 51) & (df['sex'] == 1)]['marital-status']
more_married = more_married.value_counts()
print(more_married)
# Out:
#  Married-civ-spouse       5938
#  Never-married             325
#  Divorced                  284
#  Separated                  49
#  Widowed                    39
#  Married-spouse-absent      23
#  Married-AF-spouse           4
# Name: marital-status, dtype: int64

# %%
#9. What is the maximum number of hours a person works per week (hours-per-week feature)?
# How many people work such a number of hours, and what is the percentage of those who earn a lot (>50K) among them?

# %%
df['hours-per-week'].max()
# Out:
# 99

# %%
more_work = df[(df['hours-per-week'] == 99)]['hours-per-week']
more_work = more_work.value_counts()
print(more_work)
# Out:
# 99    85
# Name: hours-per-week, dtype: int64

# %%
more_work_above = df[(df['hours-per-week'] == 99) & (df['salary'] == 51)]['hours-per-week']
more_work_above = more_work_above.value_counts()
print(more_work_above)
# Out:
# 99    25
# Name: hours-per-week, dtype: int64

# %%
tot = (  more_work_above / more_work) * 100
print(tot)
# Out:
# 99    29.411765
# Name: hours-per-week, dtype: float64

# %%
#10. Count the average time of work (hours-per-week) for those who earn a little and a lot (salary) for each country (native-country). 
#What will these be for Japan?

# %%
df['hours-per-week'].mean()
# Out:
# 40.437455852092995

# %%
dk1 = df.groupby(['native-country', 'hours-per-week'])
dk1.describe()
# Out:
#                                 age                                           \
#                               count  mean        std   min   25%   50%   75%
# native-country hours-per-week
#  1             6                1.0  69.0        NaN  69.0  69.0  69.0  69.0
#                8                1.0  74.0        NaN  74.0  74.0  74.0  74.0
#                10               2.0  44.0  32.526912  21.0  32.5  44.0  55.5
#                12               1.0  20.0        NaN  20.0  20.0  20.0  20.0
#                15               3.0  51.0  25.709920  22.0  41.0  60.0  65.5
# ...                             ...   ...        ...   ...   ...   ...   ...
#  Yugoslavia    50               1.0  56.0        NaN  56.0  56.0  56.0  56.0
#                52               1.0  29.0        NaN  29.0  29.0  29.0  29.0
#                60               1.0  36.0        NaN  36.0  36.0  36.0  36.0
#                65               1.0  35.0        NaN  35.0  35.0  35.0  35.0
# ...

# %%
more_country = df['native-country'] == "Japan"
more_country = more_country.value_counts()
print(more_country)
# Out:
# False    32561
# Name: native-country, dtype: int64

# %%
more_country = df[(df['salary'] == 51)]['hours-per-week']
more_country = more_country.value_counts()
print(more_country)
# Out:
# 40    3247
# 50    1276
# 45     685
# 60     648
# 55     323
#       ...
# 95       1
# 29       1
# 17       1
# 96       1
# 73       1
# Name: hours-per-week, Length: 80, dtype: int64

# %%
more_country_salary = (df['native-country'] == 'Japan')
print(more_country_salary)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: native-country, Length: 32561, dtype: bool

# %%
more_country = df[(df['native-country'] != 'Japan') & (df['salary'] == 51)]['hours-per-week'].mean()
print(more_country)
# Out:
# 45.473026399693914

# %%
j = df['native-country'] == 'Japan'
k = df['hours-per-week'] > df['hours-per-week'].mean()
dk2 = df.groupby([k,'salary'])
dk2.describe()
# Out:
#                            age                                                \
#                          count       mean        std   min   25%   50%   75%
# hours-per-week salary
# False          50      18995.0  36.467491  14.659877  17.0  24.0  33.0  46.0
#                51       3985.0  45.256713  11.004476  19.0  37.0  45.0  52.0
# True           50       5725.0  37.833013  11.587756  17.0  29.0  36.0  45.0
#                51       3856.0  43.209284   9.886832  19.0  36.0  42.0  50.0
#
#                               fnlwgt                                         \
#                         max    count           mean            std      min
# hours-per-week salary
# False          50      90.0  18995.0  192919.823217  107034.925479  12285.0
#                51      90.0   3985.0  187203.522208  100875.194387  14878.0
# True           50      90.0   5725.0  181784.130131  104180.558238  19302.0
#                51      90.0   3856.0  188833.290716  104242.737064  19302.0
#
# ...

# %%
more_country = df[(df['salary'] == 50)]['native-country']
more_country = more_country.value_counts()
print(more_country)
# Out:
#  United-States                 21999
#  Mexico                          610
#  ?                               437
#  Philippines                     137
#  Puerto-Rico                     102
#  El-Salvador                      97
#  1                                93
#  Canada                           82
#  Jamaica                          71
#  Cuba                             70
#  Dominican-Republic               68
#  South                            64
#  Vietnam                          62
#  Guatemala                        61
#  England                          60
#  India                            60
#  Columbia                         57
#  China                            55
#  Poland                           48
#  Italy                            48
#  Haiti                            40
#  Japan                            38
#  Portugal                         33
#  Nicaragua                        32
#  Taiwan                           31
# ...
